# %% [markdown]
# QAZEEM ANUOLUWAPO
# +234 7089225441
# ROYALANNIE2002@GMAIL.COM
# DATA SCIENTIST

# %% [markdown]
# Storytelling for the project:
#
# Title: Food Preference Analysis
#
# Objective: To analyze the food preferences of participants from different nationalities and age groups.
#
#  i collected the dataset from kaggle  to understand the food preferences of people from different nationalities and age groups. the dataset consists of responses from 288 participants, with information about their nationality, age, and preferences for different types of food, juice, and desserts.
#
# Through my analysis, i aim to identify patterns and correlations in food preferences across different nationalities and age groups. i will use visualizations to illustrate the distribution of participants by nationality, age, and gender, as well as the correlation between food, juice, and dessert preferences. my findings will provide insights into the food preferences of different demographics, which can be useful for food manufacturers, restaurants, and marketers.

# %%
#IMPORT THE NECCESARY LIBRIRIES
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#IMPORT THE DATASET
food = pd.read_csv('Food_Preference.csv')

# %%
food
# Out:
#                         Timestamp Participant_ID  Gender Nationality  Age  \
# 0     2019/05/07 2:59:13 PM GMT+8         FPS001    Male      Indian   24
# 1     2019/05/07 2:59:45 PM GMT+8         FPS002  Female      Indian   22
# 2     2019/05/07 3:00:05 PM GMT+8         FPS003    Male      Indian   31
# 3     2019/05/07 3:00:11 PM GMT+8         FPS004  Female      Indian   25
# 4     2019/05/07 3:02:50 PM GMT+8         FPS005    Male      Indian   27
# ..                            ...            ...     ...         ...  ...
# 283   2019/05/10 9:24:00 AM GMT+8         FPS284    Male      Indian   27
# 284   2019/05/10 9:32:54 AM GMT+8         FPS285    Male      Indian   24
# 285  2019/05/10 12:09:17 PM GMT+8         FPS286    Male      Indian   25
# 286  2019/05/10 12:52:17 PM GMT+8         FPS287    Male      Indian   27
# 287  2019/05/10 12:55:42 PM GMT+8         FPS288    Male      Indian   27
#
#                  Food              Juice Dessert
# ...

# %% [markdown]
# ### DATA INSPECTION

# %%
food.head()
# Out:
#                      Timestamp Participant_ID  Gender Nationality  Age  \
# 0  2019/05/07 2:59:13 PM GMT+8         FPS001    Male      Indian   24
# 1  2019/05/07 2:59:45 PM GMT+8         FPS002  Female      Indian   22
# 2  2019/05/07 3:00:05 PM GMT+8         FPS003    Male      Indian   31
# 3  2019/05/07 3:00:11 PM GMT+8         FPS004  Female      Indian   25
# 4  2019/05/07 3:02:50 PM GMT+8         FPS005    Male      Indian   27
#
#                Food              Juice Dessert
# 0  Traditional food        Fresh Juice   Maybe
# 1      Western Food  Carbonated drinks     Yes
# 2      Western Food        Fresh Juice   Maybe
# 3  Traditional food        Fresh Juice   Maybe
# 4  Traditional food        Fresh Juice   Maybe

# %%
food.shape
# Out:
# (288, 8)

# %%
food.columns
# Out:
# Index(['Timestamp', 'Participant_ID', 'Gender', 'Nationality', 'Age', 'Food',
#        'Juice', 'Dessert'],
#       dtype='object')

# %%
food.index
# Out:
# RangeIndex(start=0, stop=288, step=1)

# %%
food.dtypes
# Out:
# Timestamp         object
# Participant_ID    object
# Gender            object
# Nationality       object
# Age                int64
# Food              object
# Juice             object
# Dessert           object
# dtype: object

# %%
food.nunique()
# Out:
# Timestamp         285
# Participant_ID    288
# Gender              2
# Nationality        27
# Age                49
# Food                2
# Juice               2
# Dessert             3
# dtype: int64

# %%
food.count()
# Out:
# Timestamp         288
# Participant_ID    288
# Gender            284
# Nationality       288
# Age               288
# Food              288
# Juice             288
# Dessert           288
# dtype: int64

# %%
food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 288 entries, 0 to 287
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Timestamp       288 non-null    object
#  1   Participant_ID  288 non-null    object
#  2   Gender          284 non-null    object
#  3   Nationality     288 non-null    object
#  4   Age             288 non-null    int64
#  5   Food            288 non-null    object
#  6   Juice           288 non-null    object
#  7   Dessert         288 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 18.1+ KB

# %%
print(food['Timestamp'].min())
print(food['Timestamp'].max())
# Out:
# 2019/05/07 10:25:13 PM GMT+8
# 2019/05/10 9:32:54 AM GMT+8

# %%
print(food['Participant_ID'].nunique())
# Out:
# 288

# %%
print(food[food.duplicated('Participant_ID',keep=False)])
# Out:
# Empty DataFrame
# Columns: [Timestamp, Participant_ID, Gender, Nationality, Age, Food, Juice, Dessert]
# Index: []

# %%
print(food['Gender'].value_counts())
# Out:
# Gender
# Female    165
# Male      119
# Name: count, dtype: int64

# %%
print(food['Gender'].isnull().sum())
# Out:
# 4

# %%
print(food['Nationality'].value_counts().head())
# Out:
# Nationality
# Indian       241
# Malaysian     10
# Indonesia      7
# Pakistani      3
# Japan          2
# Name: count, dtype: int64

# %%
print(food['Nationality'].value_counts().tail())
# Out:
# Nationality
# Maldivian     1
# Pakistan      1
# Muslim        1
# Tanzanian     1
# Yemen         1
# Name: count, dtype: int64

# %%
print(food['Age'].min())
print(food['Age'].max())
# Out:
# 8
# 80

# %%
print(food['Age'].describe())
# Out:
# count    288.000000
# mean      30.597222
# std       11.180383
# min        8.000000
# 25%       24.000000
# 50%       28.000000
# 75%       36.250000
# max       80.000000
# Name: Age, dtype: float64

# %%
print(food['Food'].value_counts())
# Out:
# Food
# Traditional food    238
# Western Food         50
# Name: count, dtype: int64

# %%
print(food['Juice'].value_counts())
# Out:
# Juice
# Fresh Juice          256
# Carbonated drinks     32
# Name: count, dtype: int64

# %%
print(food['Dessert'].value_counts())
# Out:
# Dessert
# Maybe    122
# Yes      114
# No        52
# Name: count, dtype: int64

# %%
food['Gender'].fillna(food['Gender'].mode()[0],inplace=True)

# %%
print(food['Gender'].value_counts())
# Out:
# Gender
# Female    169
# Male      119
# Name: count, dtype: int64

# %%
food.count()
# Out:
# Timestamp         288
# Participant_ID    288
# Gender            288
# Nationality       288
# Age               288
# Food              288
# Juice             288
# Dessert           288
# dtype: int64

# %% [markdown]
# ### DATA ANALYSIS AND VISUALIZATION

# %%
# Sample 100 rows from the DataFrame
food_sample = food.sample(n=100)

# %% [markdown]
# Participants by Nationality:
#
# This bar chart shows the number of participants from each nationality. The x-axis represents the nationality, and the y-axis represents the number of participants. The height of each bar indicates the number of participants from each nationality. This visualization helps us understand the distribution of participants across different nationalities.

# %%
# Bar chart for Nationality
plt.figure(figsize=(8,6))
sns.countplot(x='Nationality', data=food_sample)
plt.xticks(rotation=90)
plt.tight_layout()
plt.title('Participants by Nationality')
plt.show()

# %% [markdown]
#  Age Distribution:
#
# This histogram shows the distribution of participants by age. The x-axis represents the age range, and the y-axis represents the number of participants. The height of each bar indicates the number of participants in each age range. This visualization helps us understand the age demographics of the participants.

# %%
# Histogram for Age
plt.figure(figsize=(8,6))
sns.histplot(x='Age', data=food_sample, bins=10)
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# Gender Distribution:
#
# This bar chart shows the gender distribution of participants. The slices of the pie represent the proportion of male and female participants. This visualization helps us understand the gender balance of the participants.

# %%
# bar chart for Gender
plt.figure(figsize=(6,6))
sns.countplot(x='Gender', data=food_sample)
plt.title('Gender Distribution')
plt.show()

# %% [markdown]
# Correlation between Food, Juice, and Dessert preferences:
#
# This heatmap shows the correlation between the preferences for food, juice, and dessert. The x-axis and y-axis represent the different types of food, juice, and dessert, and the color of each cell indicates the strength of the correlation between each pair of preferences. This visualization helps us understand the relationships between the different preferences.
#
# These visualizations provide insights into the demographics and preferences of the participants, which can help inform marketing strategies, product development, and other business decisions.

# %%
# Stacked bar chart for Food, Juice, and Dessert preferences
plt.figure(figsize=(8,6))
sns.countplot(x='Food', data=food_sample, hue='Juice')
plt.title('Food and Juice Preferences')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Food', data=food_sample, hue='Dessert')
plt.title('Food and Dessert Preferences')
plt.show()

# %%
# Group by Nationality and plot the mean Age
plt.figure(figsize=(8,6))
sns.barplot(x='Nationality', y='Age', data=food_sample)
plt.xticks(rotation=90)
plt.tight_layout()
plt.title('Mean Age by Nationality')
plt.show()

# %%
# Group by Gender and plot the count of Food preferences
plt.figure(figsize=(8,6))
sns.countplot(x='Food', hue='Gender', data=food_sample)
plt.title('Food Preferences by Gender')
plt.show()

# %%
# Group by Juice and plot the count of Dessert preferences
plt.figure(figsize=(8,6))
sns.countplot(x='Dessert', hue='Juice', data=food_sample)
plt.title('Dessert Preferences by Juice')
plt.show()

# %%
# Group by Nationality and plot the count of Juice preferences
plt.figure(figsize=(8,6))
sns.countplot(x='Juice', hue='Nationality', data=food_sample)
plt.title('Juice Preferences by Nationality')
plt.show()

# %%
# Group by Age and plot the count of Food preferences
plt.figure(figsize=(8,6))
sns.countplot(x='Food', hue='Age', data=food_sample)
plt.title('Food Preferences by Age')
plt.show()
